# %%
# Hardware UART Transmitter using Verilog

# %%
## ****

# %%
##FSM Diagram

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_jpeg {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")

from IPython.display import Image
Image (filename = "FSM_dia.jpeg", width = 400, height = 300)
